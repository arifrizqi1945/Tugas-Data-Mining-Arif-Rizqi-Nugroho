# %% [markdown]
# 1. Download Dataset

# %%
#!pip install -q kaggle

# %% [markdown]
# 1.1 uploaded kaggle

# %%
#!mkdir -p ~/.kaggle
#!cp kaggle.json ~/.kaggle/

#!chmod 600 ~/.kaggle/kaggle.json #fungsi untuk memberikan izin akses file

# %% [markdown]
# 1.2 Processing download

# %%
#!kaggle datasets download -d akshaydattatraykhare/diabetes-dataset
#diabetes-dataset.zip: Skipping, found more recently modified local copy (use --force to force download)

#import zipfile

#with zipfile.ZipFile('diabetes-dataset.zip', 'r') as zip_ref:
#  zip_ref.extractall('/content/')

# %% [markdown]
# 2. Import Library

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.svm import SVC

# %% [markdown]
# 3. Load & Display Dataset

# %%
df = pd.read_csv('/content/diabetes.csv')
display(df.head(2)) # display fisrt record of data
display(df.tail(2)) # display last 4 rocord of data
display(df.sample(4)) # display randomly any number of record of data
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 766                     0.349   47        1
# 767                     0.315   23        0
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 415            3      173             84             33      474  35.7
# 374            2      122             52             43      158  36.2
# 117            5       78             48              0        0  33.7
# 197            3      107             62             13       48  22.9
#
#      DiabetesPedigreeFunction  Age  Outcome
# 415                     0.258   22        1
# 374                     0.816   28        0
# 117                     0.654   25        0
# 197                     0.678   23        1

# %% [markdown]
# Description

# %% [markdown]
# 3.1 The shape of dataset

# %%
#number of rows and colums
df.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-8d93dffcc9f6> in <cell line: 2>()
#       1 #number of rows and colums
# ----> 2 df.shape
#
# NameError: name 'df' is not defined

# %% [markdown]
# 3.2 List types of all columns

# %%
df.dtypes
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-5cc0934cc03c> in <cell line: 1>()
# ----> 1 df.dtypes
#
# NameError: name 'df' is not defined

# %% [markdown]
# 3.3 Info of the dataset

# %%
df.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-a74c58233b9e> in <cell line: 1>()
# ----> 1 df.info()
#
# NameError: name 'df' is not defined

# %% [markdown]
# 3.4 Summary of the dataset

# %%
df.describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-ea8415b8a3ee> in <cell line: 1>()
# ----> 1 df.describe()
#
# NameError: name 'df' is not defined

# %% [markdown]
# Check Null Value

# %% [markdown]
# 4. Data Cleaning

# %% [markdown]
# 4.1 Drp the duplicte

# %%
# check the shape before drop duplicate
df.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-24f971df204f> in <cell line: 2>()
#       1 # check the shape before drop duplicate
# ----> 2 df.shape
#
# NameError: name 'df' is not defined

# %% [markdown]
# 4.2 Check the NULL value

# %%
# check of null values,
# check the missing value in any column,
# display number of null value in every column in dataset.
df.isnull().sum()

df.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-805293d73562> in <cell line: 4>()
#       2 # check the missing value in any column,
#       3 # display number of null value in every column in dataset.
# ----> 4 df.isnull().sum()
#       5
#       6 df.columns
#
# NameError: name 'df' is not defined

# %% [markdown]
# check the no.of Zero value in dataset

# %%
print ('No of zero value in Glucose', df[df['Glucose']==0].shape[0])
print ('No of zero value in BloodPressure', df[df['BloodPressure']==0].shape[0])
print ('No of zero value in SkinThickness', df[df['SkinThickness']==0].shape[0])
  No of zero value in SkinThickness 227
print ('No of zero value in Insulin', df[df['Insulin']==0].shape[0])
print ('No of zero value in BMI', df[df['BMI']==0].shape[0])
# Out:
#   File "<ipython-input-7-84f1b37a703c>", line 4
#     No of zero value in SkinThickness 227
#     ^
# IndentationError: unexpected indent

# %% [markdown]
# Replace the no.of Zero value with mean of columns

# %%
df['Glucose']=df['Glucose'].replace(0,df['Glucose'].mean())
print('no of zero value in Glucose',df[df['Glucose']==0].shape[0])

df['BloodPressure']=df['BloodPressure'].replace(0,df['BloodPressure'].mean())
df['SkinThickness']=df['SkinThickness'].replace(0,df['SkinThickness'].mean())
df['Insulin']=df['Insulin'].replace(0,df['Insulin'].mean())
df['BMI']=df['BMI'].replace(0,df['BMI'].mean())

df.describe()

# utcome count plot
f,ax=plt.subplots (1,2,figsize=(10,5))
df['Outcome'].value_counts().plot.pie(explode=[0,0.1],autopct='%1.1f%%',ax=ax[0], shadow=True)
ax[0].set_title('Outcome')
ax[0].set_ylabel('')
sns.countplot(x='Outcome',data=df,ax=ax[1])
ax[1].set_title('Outcome')
N,P = df['Outcome'].value_counts()
print('Negative (0):',N)
print('Positive (1):',P)
plt.grid()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-eeceb1a92fdd> in <cell line: 1>()
# ----> 1 df['Glucose']=df['Glucose'].replace(0,df['Glucose'].mean())
#       2 print('no of zero value in Glucose',df[df['Glucose']==0].shape[0])
#       3
#       4 df['BloodPressure']=df['BloodPressure'].replace(0,df['BloodPressure'].mean())
#       5 df['SkinThickness']=df['SkinThickness'].replace(0,df['SkinThickness'].mean())
#
# NameError: name 'df' is not defined

# %% [markdown]
# Histogram of aech feature

# %%
df.hist (bins=10,figsize=(10,10))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-d3225db53366> in <cell line: 1>()
# ----> 1 df.hist (bins=10,figsize=(10,10))
#       2 plt.show()
#
# NameError: name 'df' is not defined

# %% [markdown]
# Scatter Plaot

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(df, figsize = (20,20));
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-5efeafb45cac> in <cell line: 2>()
#       1 from pandas.plotting import scatter_matrix
# ----> 2 scatter_matrix(df, figsize = (20,20));
#
# NameError: name 'df' is not defined

# %% [markdown]
# Analyzing relationships between variable

# %%
import seaborn as sns
corrmat = df.corr()
top_corr_features = corrmat.index
plt.figure(figsize=(10,10))
g=sns.heatmap(df[top_corr_features].corr(),annot=True,cmap="viridis")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-beea34ebf58f> in <cell line: 2>()
#       1 import seaborn as sns
# ----> 2 corrmat = df.corr()
#       3 top_corr_features = corrmat.index
#       4 plt.figure(figsize=(10,10))
#       5 g=sns.heatmap(df[top_corr_features].corr(),annot=True,cmap="viridis")
#
# NameError: name 'df' is not defined

# %% [markdown]
# 5. Split the data frame into X & Y

# %%
target_name 'Outcome'
y = df[target_name]
x = df.drop(target_name, axis=1)

x.head()

y.head()
# Out:
#   File "<ipython-input-5-8153602e07f6>", line 1
#     target_name 'Outcome'
#                 ^
# SyntaxError: invalid syntax

# %% [markdown]
# 6. Apply Feature Scalling

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(x)
SSX = scaler.transform(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-4e6e9fda99fd> in <cell line: 3>()
#       1 from sklearn.preprocessing import StandardScaler
#       2 scaler = StandardScaler()
# ----> 3 scaler.fit(x)
#       4 SSX = scaler.transform(x)
#
# NameError: name 'x' is not defined

# %% [markdown]
# 7. Train Test Split

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(SSX, y, test_size=0.2, random_state=7)

x_train.shape, y_train.shape

x_test.shape, y_test.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-1aecd15bd78c> in <cell line: 2>()
#       1 from sklearn.model_selection import train_test_split
# ----> 2 x_train, x_test, y_train, y_test = train_test_split(SSX, y, test_size=0.2, random_state=7)
#       3
#       4 x_train.shape, y_train.shape
#       5
#
# NameError: name 'SSX' is not defined

# %% [markdown]
# 8. Build the Classification Algorithms SVM

# %%
from sklearn.svm import SVC
sv=SVC()
sv.fit(x_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-a19087e144cb> in <cell line: 3>()
#       1 from sklearn.svm import SVC
#       2 sv=SVC()
# ----> 3 sv.fit(x_train, y_train)
#
# NameError: name 'x_train' is not defined

# %% [markdown]
# 9. Making Prediction

# %% [markdown]
# 9.4 SVM

# %%
sv_pred=sv.predict(x_test)

sv_pred.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-0779b6a7dcff> in <cell line: 1>()
# ----> 1 sv_pred=sv.predict(x_test)
#       2
#       3 sv_pred.shape
#
# NameError: name 'x_test' is not defined
